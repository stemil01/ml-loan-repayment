# %%
import os

import numpy as np
import pandas as pd

from sklearn import metrics

import pickle

# %%
dataset_dir = "dataset"
models_dir = "models"

# %%
data_df = pd.read_csv(os.path.join(dataset_dir, "test_set.csv"))
X_test = data_df.drop(columns=["TARGET"])
y_test = data_df["TARGET"]

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# Load the model.

# %%
model_path = os.path.join(models_dir, "lr_pipe.pkl")
with open(model_path, "rb") as file:
    lr_pipe = pickle.load(file)

# %%
y_pred = lr_pipe.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96     13792
#          1.0       0.41      0.01      0.02      1208
#
#     accuracy                           0.92     15000
#    macro avg       0.66      0.50      0.49     15000
# weighted avg       0.88      0.92      0.88     15000

# %% [markdown]
# ## XGBoost

# %%
model_path = os.path.join(models_dir, "xgb_clf.pkl")
with open(model_path, "rb") as file:
    xgb_clf = pickle.load(file)

# %%
y_pred = xgb_clf.predict(X_test)

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.96     13792
#          1.0       0.41      0.05      0.08      1208
#
#     accuracy                           0.92     15000
#    macro avg       0.67      0.52      0.52     15000
# weighted avg       0.88      0.92      0.89     15000
